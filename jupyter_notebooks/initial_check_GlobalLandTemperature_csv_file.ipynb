# %%
import pandas as pd
import os

# importing matplotlib module  
from matplotlib import pyplot as plt

# %%
file_name = "GlobalLandTemperaturesByCity.csv"
folder_path = "../data"
full_file_path = os.path.join(folder_path, file_name)

# %%
df = pd.read_csv(full_file_path)

# %%
df.head(10)
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
# 5  1744-04-01               5.788                          3.624  Århus
# 6  1744-05-01              10.644                          1.283  Århus
# 7  1744-06-01              14.051                          1.347  Århus
# 8  1744-07-01              16.082                          1.396  Århus
# 9  1744-08-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# ...

# %%
df['Country'].unique()
# Out:
# array(['Denmark', 'Turkey', 'Kazakhstan', 'China', 'Spain', 'Germany',
#        'Nigeria', 'Iran', 'Russia', 'Canada', "Côte D'Ivoire",
#        'United Kingdom', 'Saudi Arabia', 'Japan', 'United States',
#        'India', 'Benin', 'United Arab Emirates', 'Mexico', 'Venezuela',
#        'Ghana', 'Ethiopia', 'Australia', 'Yemen', 'Indonesia', 'Morocco',
#        'Pakistan', 'France', 'Libya', 'Burma', 'Brazil', 'South Africa',
#        'Syria', 'Egypt', 'Algeria', 'Netherlands', 'Malaysia', 'Portugal',
#        'Ecuador', 'Italy', 'Uzbekistan', 'Philippines', 'Madagascar',
#        'Chile', 'Belgium', 'El Salvador', 'Romania', 'Peru', 'Colombia',
#        'Tanzania', 'Tunisia', 'Turkmenistan', 'Israel', 'Eritrea',
#        'Paraguay', 'Greece', 'New Zealand', 'Vietnam', 'Cameroon', 'Iraq',
#        'Afghanistan', 'Argentina', 'Azerbaijan', 'Moldova', 'Mali',
#        'Congo (Democratic Republic Of The)', 'Thailand',
# ...

# %%
df['City'].unique()
# Out:
# array(['Århus', 'Çorlu', 'Çorum', ..., 'Zurich', 'Zuwarah', 'Zwolle'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8599212 entries, 0 to 8599211
# Data columns (total 7 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   dt                             object
#  1   AverageTemperature             float64
#  2   AverageTemperatureUncertainty  float64
#  3   City                           object
#  4   Country                        object
#  5   Latitude                       object
#  6   Longitude                      object
# dtypes: float64(2), object(5)
# memory usage: 459.2+ MB

# %%
df.describe()
# Out:
#        AverageTemperature  AverageTemperatureUncertainty
# count        8.235082e+06                   8.235082e+06
# mean         1.672743e+01                   1.028575e+00
# std          1.035344e+01                   1.129733e+00
# min         -4.270400e+01                   3.400000e-02
# 25%          1.029900e+01                   3.370000e-01
# 50%          1.883100e+01                   5.910000e-01
# 75%          2.521000e+01                   1.349000e+00
# max          3.965100e+01                   1.539600e+01

# %%
df_temp = df[['dt', 'AverageTemperature', 'City', 'Country']]

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
df.tail()
# Out:
#                  dt  AverageTemperature  AverageTemperatureUncertainty  \
# 8599207  2013-05-01              11.464                          0.236
# 8599208  2013-06-01              15.043                          0.261
# 8599209  2013-07-01              18.775                          0.193
# 8599210  2013-08-01              18.025                          0.298
# 8599211  2013-09-01                 NaN                            NaN
#
#            City      Country Latitude Longitude
# 8599207  Zwolle  Netherlands   52.24N     5.26E
# 8599208  Zwolle  Netherlands   52.24N     5.26E
# 8599209  Zwolle  Netherlands   52.24N     5.26E
# 8599210  Zwolle  Netherlands   52.24N     5.26E
# 8599211  Zwolle  Netherlands   52.24N     5.26E

# %%
df_plot =  df_temp[(df_temp['Country'] == 'Brazil')]
df_plot.head()
# Out:
#                 dt  AverageTemperature        City Country
# 152741  1832-01-01              25.953  Alagoinhas  Brazil
# 152742  1832-02-01              25.933  Alagoinhas  Brazil
# 152743  1832-03-01              25.968  Alagoinhas  Brazil
# 152744  1832-04-01              25.100  Alagoinhas  Brazil
# 152745  1832-05-01              24.213  Alagoinhas  Brazil

# %%
y = df_plot['AverageTemperature']
x = df_plot['dt']

plt.figure(figsize=(15,5))
plt.scatter(x, y) 
  
# function to show the plot  
plt.show()

# %%
df['year'] = pd.DatetimeIndex(df['dt']).year
df_temp_2 = df[['dt', 'AverageTemperature', 'City', 'Country', 'year']]
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude  year
# 0  Denmark   57.05N    10.33E  1743
# 1  Denmark   57.05N    10.33E  1743
# 2  Denmark   57.05N    10.33E  1744
# 3  Denmark   57.05N    10.33E  1744
# 4  Denmark   57.05N    10.33E  1744

# %%
df_temp_2
# Out:
#                  dt  AverageTemperature    City      Country  year
# 0        1743-11-01               6.068   Århus      Denmark  1743
# 1        1743-12-01                 NaN   Århus      Denmark  1743
# 2        1744-01-01                 NaN   Århus      Denmark  1744
# 3        1744-02-01                 NaN   Århus      Denmark  1744
# 4        1744-03-01                 NaN   Århus      Denmark  1744
# ...             ...                 ...     ...          ...   ...
# 8599207  2013-05-01              11.464  Zwolle  Netherlands  2013
# 8599208  2013-06-01              15.043  Zwolle  Netherlands  2013
# 8599209  2013-07-01              18.775  Zwolle  Netherlands  2013
# 8599210  2013-08-01              18.025  Zwolle  Netherlands  2013
# 8599211  2013-09-01                 NaN  Zwolle  Netherlands  2013
#
# [8599212 rows x 5 columns]

# %%
df_plot_2 =  df_temp[(df_temp_2['Country'] == 'Brazil') & (df_temp_2['year'] >= 2010)]

# %%
df_temp_2
# Out:
#                  dt  AverageTemperature    City      Country  year
# 0        1743-11-01               6.068   Århus      Denmark  1743
# 1        1743-12-01                 NaN   Århus      Denmark  1743
# 2        1744-01-01                 NaN   Århus      Denmark  1744
# 3        1744-02-01                 NaN   Århus      Denmark  1744
# 4        1744-03-01                 NaN   Århus      Denmark  1744
# ...             ...                 ...     ...          ...   ...
# 8599207  2013-05-01              11.464  Zwolle  Netherlands  2013
# 8599208  2013-06-01              15.043  Zwolle  Netherlands  2013
# 8599209  2013-07-01              18.775  Zwolle  Netherlands  2013
# 8599210  2013-08-01              18.025  Zwolle  Netherlands  2013
# 8599211  2013-09-01                 NaN  Zwolle  Netherlands  2013
#
# [8599212 rows x 5 columns]

# %%
x = df_plot_2['year']
y = df_plot_2['AverageTemperature']

plt.figure(figsize=(20,4))
plt.scatter(x, y) 
  
# function to show the plot  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-42fe5d55cc0f> in <module>
# ----> 1 x = df_plot_2['year']
# ...
