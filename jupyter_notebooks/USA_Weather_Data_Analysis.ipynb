# %%
import pandas as pd

from matplotlib import pyplot as plt

# %% [markdown]
# # USA Data Analysis

# %%
import os
import glob
import pandas as pd

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('../data/usa/*.csv')]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_usa.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("combined_usa.csv")

# %% [markdown]
# ## Descriptive Data

# %%
df.head(10)
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2008-08-10        30        18           0.0     13.7        7
# 1  2008-08-11        32        18           0.0     13.7        7
# 2  2008-08-12        26        18           0.0     12.1        5
# 3  2008-08-13        26        18           0.0     12.1        5
# 4  2008-08-14        30        18           0.0     13.7        5
# 5  2008-08-15        31        18           0.0     13.2        7
# 6  2008-08-16        31        21           0.0     11.6        7
# 7  2008-08-17        30        19           0.0     11.6        6
# 8  2008-08-18        30        20           0.0     11.6        6
# 9  2008-08-19        32        20           0.0     11.6        7
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 57  03:11 PM  12:04 AM  05:56 AM  ...           12
# 1                 65  04:05 PM  12:49 AM  05:57 AM  ...           13
# ...

# %%
df.tail()
# Out:
#          date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 108243  2019-03-07         4        -7           0.0     11.6        1
# 108244  2019-03-08         5        -3           0.0      5.9        1
# 108245  2019-03-09         7         0           0.0      7.3        1
# 108246  2019-03-10        12         2           0.0      7.3        2
# 108247  2019-03-11        13         9           0.0     10.2        3
#
#         moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 108243                  3  07:20 AM  07:09 PM  06:32 AM  ...           13
# 108244                 10  07:47 AM  08:06 PM  06:30 AM  ...            9
# 108245                 17  08:14 AM  09:05 PM  06:29 AM  ...           10
# 108246                 24  08:43 AM  10:05 PM  06:27 AM  ...           19
# 108247                 32  09:14 AM  11:07 PM  06:26 AM  ...           23
#
#         cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
df.describe()
# Out:
#             maxtempC       mintempC   totalSnow_cm        sunHour  \
# count  108248.000000  108248.000000  108248.000000  108248.000000
# mean       18.884746       9.442909       0.040899      10.352468
# std        10.621848       8.892810       0.397405       3.205217
# min       -25.000000     -29.000000       0.000000       3.200000
# 25%        11.000000       3.000000       0.000000       8.700000
# 50%        20.000000      10.000000       0.000000      10.900000
# 75%        27.000000      16.000000       0.000000      13.300000
# max        47.000000      36.000000      22.900000      14.500000
#
#              uvIndex  moon_illumination      DewPointC     FeelsLikeC  \
# count  108248.000000      108248.000000  108248.000000  108248.000000
# mean        4.177685          46.107346       6.547262      13.680567
# std         2.000306          31.276926       8.788130      11.345656
# min         1.000000           0.000000     -30.000000     -39.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108248 entries, 0 to 108247
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   date_time          108248 non-null  object
#  1   maxtempC           108248 non-null  int64
#  2   mintempC           108248 non-null  int64
#  3   totalSnow_cm       108248 non-null  float64
#  4   sunHour            108248 non-null  float64
#  5   uvIndex            108248 non-null  int64
#  6   moon_illumination  108248 non-null  int64
#  7   moonrise           108248 non-null  object
#  8   moonset            108248 non-null  object
#  9   sunrise            108248 non-null  object
#  10  sunset             108248 non-null  object
#  11  DewPointC          108248 non-null  int64
#  12  FeelsLikeC         108248 non-null  int64
#  13  HeatIndexC         108248 non-null  int64
#  14  WindChillC         108248 non-null  int64
# ...

# %%
df_temp = df[['date_time', 'tempC', 'precipMM']]

# %%
df_temp.head()
# Out:
#     date_time  tempC  precipMM
# 0  2008-08-10     30       0.0
# 1  2008-08-11     32       0.0
# 2  2008-08-12     26       0.4
# 3  2008-08-13     26       1.5
# 4  2008-08-14     30       0.4

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df.date_time, df.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df.date_time, df.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_usa_all.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Years Analysis

# %%
df_usa_time_range_0813 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2013-08-11')]

# %%
x = df_usa_time_range_0813['date_time']
y = df_usa_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_usa_time_range_0813.date_time, df_usa_time_range_0813.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_usa_time_range_0813.date_time, df_usa_time_range_0813.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_usa_5years.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Year Analysis

# %%
df_usa_time_range_0809 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2009-08-10')]

# %%
x = df_usa_time_range_0809['date_time']
y = df_usa_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_usa_time_range_0809.date_time, df_usa_time_range_0809.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_usa_time_range_0809.date_time, df_usa_time_range_0809.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_usa_1year.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Months Analysis

# %%
df_usa_time_range_08_fin = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-12-30')]

# %%
x = df_usa_time_range_08_fin['date_time']
y = df_usa_time_range_08_fin['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_usa_time_range_08_fin.date_time, df_usa_time_range_08_fin.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_usa_time_range_08_fin.date_time, df_usa_time_range_08_fin.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_usa_5months.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Month Analysis

# %%
df_usa_time_range_08_aug = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-08-30')]

# %%
x = df_usa_time_range_08_aug['date_time']
y = df_usa_time_range_08_aug['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_usa_time_range_08_aug.date_time, df_usa_time_range_08_aug.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_usa_time_range_08_aug.date_time, df_usa_time_range_08_aug.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_usa_aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Week Analysis

# %%
df_usa_time_range_08_w1 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-08-17')]

# %%
x = df_usa_time_range_08_w1['date_time']
y = df_usa_time_range_08_w1['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_usa_time_range_08_w1.date_time, df_usa_time_range_08_w1.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_usa_time_range_08_w1.date_time, df_usa_time_range_08_w1.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_usa_1week.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Day Analysis

# %%
df_usa_time_range_08_d10 = df_temp.loc[(df_temp['date_time'] == '2008-08-10')]

# %%
x = df_usa_time_range_08_d10['date_time']
y = df_usa_time_range_08_d10['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_usa_time_range_08_d10.date_time, df_usa_time_range_08_d10.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_usa_time_range_08_d10.date_time, df_usa_time_range_08_d10.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_usa_10aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
