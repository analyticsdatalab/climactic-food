# %%
import pandas as pd

from matplotlib import pyplot as plt

# %% [markdown]
# # India Data Analysis

# %%
import os
import glob
import pandas as pd

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('../data/india/*.csv')]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_india.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("combined_india.csv")

# %% [markdown]
# ## Descriptive Data

# %%
df.head(10)
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2008-08-10        34        27           0.0     12.1        7
# 1  2008-08-11        31        26           0.0     12.0        6
# 2  2008-08-12        30        26           0.0      8.2        6
# 3  2008-08-13        31        26           0.0     12.0        6
# 4  2008-08-14        31        26           0.0     13.1        6
# 5  2008-08-15        29        26           0.0      8.2        6
# 6  2008-08-16        30        26           0.0     10.7        6
# 7  2008-08-17        30        26           0.0     10.7        6
# 8  2008-08-18        31        25           0.0     13.0        6
# 9  2008-08-19        31        24           0.0     13.0        7
#
#    moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# 0                 57  02:07 PM  No moonset  05:47 AM  ...            8
# 1                 65  03:01 PM    12:28 AM  05:47 AM  ...           13
# ...

# %%
df.tail()
# Out:
#         date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 46387  2019-03-07        29        19           0.0     11.6        7
# 46388  2019-03-08        30        21           0.0     11.6        7
# 46389  2019-03-09        32        20           0.0     11.6        7
# 46390  2019-03-10        34        21           0.0     11.6        7
# 46391  2019-03-11        35        24           0.0     11.6        8
#
#        moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 46387                  3  06:46 AM  06:40 PM  06:16 AM  ...           14
# 46388                 10  07:20 AM  07:32 PM  06:15 AM  ...           14
# 46389                 17  07:54 AM  08:24 PM  06:14 AM  ...           13
# 46390                 24  08:28 AM  09:17 PM  06:13 AM  ...            9
# 46391                 32  09:04 AM  10:11 PM  06:12 AM  ...            8
#
#        cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
df.describe()
# Out:
#            maxtempC      mintempC  totalSnow_cm       sunHour       uvIndex  \
# count  46392.000000  46392.000000       46392.0  46392.000000  46392.000000
# mean      32.309191     21.977388           0.0     10.951793      6.953914
# std        5.767482      6.328115           0.0      1.950477      1.321842
# min       12.000000      1.000000           0.0      3.800000      3.000000
# 25%       29.000000     18.000000           0.0      8.700000      6.000000
# 50%       32.000000     23.000000           0.0     11.600000      7.000000
# 75%       36.000000     27.000000           0.0     12.500000      8.000000
# max       50.000000     37.000000           0.0     14.000000     11.000000
#
#        moon_illumination     DewPointC    FeelsLikeC    HeatIndexC  \
# count       46392.000000  46392.000000  46392.000000  46392.000000
# mean           46.107346     14.615731     30.006165     30.037485
# std            31.277118      8.121999      7.003444      6.944158
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46392 entries, 0 to 46391
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          46392 non-null  object
#  1   maxtempC           46392 non-null  int64
#  2   mintempC           46392 non-null  int64
#  3   totalSnow_cm       46392 non-null  float64
#  4   sunHour            46392 non-null  float64
#  5   uvIndex            46392 non-null  int64
#  6   moon_illumination  46392 non-null  int64
#  7   moonrise           46392 non-null  object
#  8   moonset            46392 non-null  object
#  9   sunrise            46392 non-null  object
#  10  sunset             46392 non-null  object
#  11  DewPointC          46392 non-null  int64
#  12  FeelsLikeC         46392 non-null  int64
#  13  HeatIndexC         46392 non-null  int64
#  14  WindChillC         46392 non-null  int64
#  15  WindGustKmph       46392 non-null  int64
# ...

# %%
df_temp = df[['date_time', 'tempC', 'precipMM']]

# %%
df_temp.head()
# Out:
#     date_time  tempC  precipMM
# 0  2008-08-10     34       5.9
# 1  2008-08-11     31       4.3
# 2  2008-08-12     30      16.7
# 3  2008-08-13     31      10.4
# 4  2008-08-14     31       6.8

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df.date_time, df.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df.date_time, df.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_india_all.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Year Analysis

# %%
df_india_time_range_0813 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2013-08-11')]

# %%
x = df_india_time_range_0813['date_time']
y = df_india_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_india_time_range_0813.date_time, df_india_time_range_0813.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_india_time_range_0813.date_time, df_india_time_range_0813.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_india_5years.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Year Analysis

# %%
df_india_time_range_0809 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2009-08-10')]

# %%
x = df_india_time_range_0809['date_time']
y = df_india_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_india_time_range_0809.date_time, df_india_time_range_0809.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_india_time_range_0809.date_time, df_india_time_range_0809.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_india_1year.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Months Analysis

# %%
df_india_time_range_08_fin = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-12-30')]

# %%
x = df_india_time_range_08_fin['date_time']
y = df_india_time_range_08_fin['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_india_time_range_08_fin.date_time, df_india_time_range_08_fin.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_india_time_range_08_fin.date_time, df_india_time_range_08_fin.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_india_5months.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Month Analysis

# %%
df_india_time_range_08_aug = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-08-30')]

# %%
x = df_india_time_range_08_aug['date_time']
y = df_india_time_range_08_aug['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_india_time_range_08_aug.date_time, df_india_time_range_08_aug.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_india_time_range_08_aug.date_time, df_india_time_range_08_aug.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_india_aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Week Analysis

# %%
df_india_time_range_08_w1 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-08-17')]

# %%
x = df_india_time_range_08_w1['date_time']
y = df_india_time_range_08_w1['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_india_time_range_08_w1.date_time, df_india_time_range_08_w1.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_india_time_range_08_w1.date_time, df_india_time_range_08_w1.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_india_1week.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Day Analysis

# %%
df_india_time_range_08_d10 = df_temp.loc[(df_temp['date_time'] == '2008-08-10')]

# %%
x = df_india_time_range_08_d10['date_time']
y = df_india_time_range_08_d10['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_india_time_range_08_d10.date_time, df_india_time_range_08_d10.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_india_time_range_08_d10.date_time, df_india_time_range_08_d10.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_india_10aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
