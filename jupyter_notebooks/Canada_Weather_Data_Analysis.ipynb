# %%
import pandas as pd

from matplotlib import pyplot as plt

# %%
import os
import glob
import pandas as pd

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('../data/canada/*.csv')]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_canada.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("combined_canada.csv")

# %%
avg_temp = df.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp
# Out:
#        date_time      tempC
# 0     2008-08-10  20.888889
# 1     2008-08-11  20.888889
# 2     2008-08-12  21.333333
# 3     2008-08-13  21.777778
# 4     2008-08-14  24.333333
# ...          ...        ...
# 3861  2019-03-07  -4.555556
# 3862  2019-03-08  -0.555556
# 3863  2019-03-09   1.444444
# 3864  2019-03-10   3.111111
# 3865  2019-03-11   2.333333
#
# [3866 rows x 2 columns]

# %%
avg_temp_df = avg_temp.join(df['precipMM'])
avg_temp_df
# Out:
#        date_time      tempC  precipMM
# 0     2008-08-10  20.888889       0.0
# 1     2008-08-11  20.888889       0.0
# 2     2008-08-12  21.333333       0.0
# 3     2008-08-13  21.777778       0.0
# 4     2008-08-14  24.333333       0.0
# ...          ...        ...       ...
# 3861  2019-03-07  -4.555556       1.4
# 3862  2019-03-08  -0.555556       4.2
# 3863  2019-03-09   1.444444       0.1
# 3864  2019-03-10   3.111111       0.2
# 3865  2019-03-11   2.333333       0.0
#
# [3866 rows x 3 columns]

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df.date_time, avg_temp_df.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df.date_time, avg_temp_df.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_canada_all.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Year Analysis

# %%
df_canada_time_range_0813 = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2013-08-11')]

# %%
x = df_canada_time_range_0813['date_time']
y = df_canada_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_canada_time_range_0813.date_time, df_canada_time_range_0813.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_canada_time_range_0813.date_time, df_canada_time_range_0813.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_canada_5years.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ##  1 Year Analysis

# %%
df_canada_time_range_0809 = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2009-08-10')]

# %%
x = df_canada_time_range_0809['date_time']
y = df_canada_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_canada_time_range_0809.date_time, df_canada_time_range_0809.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_canada_time_range_0809.date_time, df_canada_time_range_0809.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_canada_1year.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Months Analysis

# %%
df_canada_time_range_08_fin = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2008-12-30')]

# %%
x = df_canada_time_range_08_fin['date_time']
y = df_canada_time_range_08_fin['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_canada_time_range_08_fin.date_time, df_canada_time_range_08_fin.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_canada_time_range_08_fin.date_time, df_canada_time_range_08_fin.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_canada_5months.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Month Analysis

# %%
df_canada_time_range_08_aug = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2008-08-30')]

# %%
x = df_canada_time_range_08_aug['date_time']
y = df_canada_time_range_08_aug['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_canada_time_range_08_aug.date_time, df_canada_time_range_08_aug.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_canada_time_range_08_aug.date_time, df_canada_time_range_08_aug.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_canada_aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Week Analysis

# %%
df_canada_time_range_08_w1 = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2008-08-17')]

# %%
x = df_canada_time_range_08_w1['date_time']
y = df_canada_time_range_08_w1['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_canada_time_range_08_w1.date_time, df_canada_time_range_08_w1.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_canada_time_range_08_w1.date_time, df_canada_time_range_08_w1.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_canada_1week.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
