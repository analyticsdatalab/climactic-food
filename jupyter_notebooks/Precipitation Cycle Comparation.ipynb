# %%
import pandas as pd
import os

from matplotlib import pyplot as plt

# %% [markdown]
# ## Americana, Brasil Data Analysis

# %%
file_name = "americana.csv"
folder_path = "../../../WorldWeatherOnline/data"
full_file_path = os.path.join(folder_path, file_name)

# %%
df = pd.read_csv(full_file_path)

# %%
df.head(10)
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2008-08-10        23        15           0.0      8.7        4
# 1  2008-08-11        26        14           0.0      8.7        5
# 2  2008-08-12        28        17           0.0      8.7        6
# 3  2008-08-13        28        18           0.0      8.7        6
# 4  2008-08-14        25        17           0.0      8.7        6
# 5  2008-08-15        27        16           0.0      8.7        6
# 6  2008-08-16        27        17           0.0      8.7        6
# 7  2008-08-17        28        17           0.0      8.7        6
# 8  2008-08-18        29        16           0.0      8.7        6
# 9  2008-08-19        29        16           0.0      8.7        6
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 57  12:25 PM  01:37 AM  06:37 AM  ...           16
# 1                 65  01:14 PM  02:31 AM  06:37 AM  ...           11
# ...

# %%
df.describe()
# Out:
#           maxtempC     mintempC  totalSnow_cm      sunHour      uvIndex  \
# count  3866.000000  3866.000000        3866.0  3866.000000  3866.000000
# mean     26.679772    16.809881           0.0    10.455484     5.282204
# std       3.675222     3.247818           0.0     2.307258     0.869955
# min       9.000000     3.000000           0.0     4.100000     2.000000
# 25%      24.000000    15.000000           0.0     8.700000     5.000000
# 50%      27.000000    17.000000           0.0    10.800000     5.000000
# 75%      29.000000    19.000000           0.0    12.800000     6.000000
# max      39.000000    25.000000           0.0    13.700000     8.000000
#
#        moon_illumination    DewPointC   FeelsLikeC   HeatIndexC   WindChillC  \
# count        3866.000000  3866.000000  3866.000000  3866.000000  3866.000000
# mean           46.107346    16.994309    22.312209    22.515779    21.453440
# std            31.280827     3.508698     3.878630     3.693130     3.122514
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3866 entries, 0 to 3865
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          3866 non-null   object
#  1   maxtempC           3866 non-null   int64
#  2   mintempC           3866 non-null   int64
#  3   totalSnow_cm       3866 non-null   float64
#  4   sunHour            3866 non-null   float64
#  5   uvIndex            3866 non-null   int64
#  6   moon_illumination  3866 non-null   int64
#  7   moonrise           3866 non-null   object
#  8   moonset            3866 non-null   object
#  9   sunrise            3866 non-null   object
#  10  sunset             3866 non-null   object
#  11  DewPointC          3866 non-null   int64
#  12  FeelsLikeC         3866 non-null   int64
#  13  HeatIndexC         3866 non-null   int64
#  14  WindChillC         3866 non-null   int64
#  15  WindGustKmph       3866 non-null   int64
# ...

# %%
df_temp = df[['date_time', 'maxtempC', 'mintempC', 'tempC', 'precipMM']]

# %%
df_temp.head(10)
# Out:
#     date_time  maxtempC  mintempC  tempC  precipMM
# 0  2008-08-10        23        15     23       1.4
# 1  2008-08-11        26        14     26       0.1
# 2  2008-08-12        28        17     28       0.0
# 3  2008-08-13        28        18     28       0.0
# 4  2008-08-14        25        17     25       0.0
# 5  2008-08-15        27        16     27       0.0
# 6  2008-08-16        27        17     27       0.0
# 7  2008-08-17        28        17     28       0.0
# 8  2008-08-18        29        16     29       0.0
# 9  2008-08-19        29        16     29       0.0

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df.date_time, df.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df.date_time, df.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
