# %%
import os
import glob
import pandas as pd

from matplotlib import pyplot as plt

# %% [markdown]
# # Importing Data

# %% [markdown]
# ## ASIA

# %% [markdown]
# ### INDIA

# %%
extension = 'csv'
india_all_filenames = [i for i in glob.glob('../data/india/*.csv')]

# %%
#combine all files in the list
india_combined_csv = pd.concat([pd.read_csv(f) for f in india_all_filenames ])
#export to csv
india_combined_csv.to_csv( "combined_india.csv", index=False, encoding='utf-8-sig')

# %%
df_india = pd.read_csv("combined_india.csv")

# %% [markdown]
# ### CHINA

# %%
extension = 'csv'
china_all_filenames = [i for i in glob.glob('../data/china/*.csv')]

# %%
#combine all files in the list
china_combined_csv = pd.concat([pd.read_csv(f) for f in china_all_filenames ])
#export to csv
china_combined_csv.to_csv( "combined_china.csv", index=False, encoding='utf-8-sig')

# %%
df_china = pd.read_csv("combined_china.csv")

# %% [markdown]
# ### JAPAN

# %%
extension = 'csv'
japan_all_filenames = [i for i in glob.glob('../data/japan/*.csv')]

# %%
#combine all files in the list
japan_combined_csv = pd.concat([pd.read_csv(f) for f in japan_all_filenames ])
#export to csv
japan_combined_csv.to_csv( "combined_japan.csv", index=False, encoding='utf-8-sig')

# %%
df_japan = pd.read_csv("combined_japan.csv")

# %% [markdown]
# ### RUSSIA

# %%
extension = 'csv'
russia_all_filenames = [i for i in glob.glob('../data/russia/*.csv')]

# %%
#combine all files in the list
russia_combined_csv = pd.concat([pd.read_csv(f) for f in russia_all_filenames ])
#export to csv
russia_combined_csv.to_csv( "combined_russia.csv", index=False, encoding='utf-8-sig')

# %%
df_russia = pd.read_csv("combined_russia.csv")

# %% [markdown]
# ## AMERICA

# %% [markdown]
# ### BRAZIL

# %%
extension = 'csv'
brazil_all_filenames = [i for i in glob.glob('../data/brazil/*.csv')]

# %%
#combine all files in the list
brazil_combined_csv = pd.concat([pd.read_csv(f) for f in brazil_all_filenames ])
#export to csv
brazil_combined_csv.to_csv( "combined_brazil.csv", index=False, encoding='utf-8-sig')

# %%
df_brazil = pd.read_csv("combined_brazil.csv")

# %% [markdown]
# ### USA

# %%
extension = 'csv'
usa_all_filenames = [i for i in glob.glob('../data/usa/*.csv')]

# %%
#combine all files in the list
usa_combined_csv = pd.concat([pd.read_csv(f) for f in usa_all_filenames ])
#export to csv
usa_combined_csv.to_csv( "combined_usa.csv", index=False, encoding='utf-8-sig')

# %%
df_usa = pd.read_csv("combined_usa.csv")

# %% [markdown]
# ## EUROPE

# %% [markdown]
# ### ROMANIA

# %%
extension = 'csv'
romania_all_filenames = [i for i in glob.glob('../data/romania/*.csv')]

# %%
#combine all files in the list
romania_combined_csv = pd.concat([pd.read_csv(f) for f in romania_all_filenames ])
#export to csv
romania_combined_csv.to_csv( "combined_romania.csv", index=False, encoding='utf-8-sig')

# %%
df_romania = pd.read_csv("combined_romania.csv")

# %% [markdown]
# ### FRANCE

# %%
extension = 'csv'
france_all_filenames = [i for i in glob.glob('../data/france/*.csv')]

# %%
#combine all files in the list
france_combined_csv = pd.concat([pd.read_csv(f) for f in france_all_filenames ])
#export to csv
france_combined_csv.to_csv( "combined_france.csv", index=False, encoding='utf-8-sig')

# %%
df_france = pd.read_csv("combined_france.csv")

# %% [markdown]
# ### GERMANY

# %%
extension = 'csv'
germany_all_filenames = [i for i in glob.glob('../data/germany/*.csv')]

# %%
#combine all files in the list
germany_combined_csv = pd.concat([pd.read_csv(f) for f in germany_all_filenames ])
#export to csv
germany_combined_csv.to_csv( "combined_germany.csv", index=False, encoding='utf-8-sig')

# %%
df_germany = pd.read_csv("combined_germany.csv")

# %% [markdown]
# ### SPAIN

# %%
extension = 'csv'
spain_all_filenames = [i for i in glob.glob('../data/spain/*.csv')]

# %%
#combine all files in the list
spain_combined_csv = pd.concat([pd.read_csv(f) for f in spain_all_filenames ])
#export to csv
spain_combined_csv.to_csv( "combined_spain.csv", index=False, encoding='utf-8-sig')

# %%
df_spain = pd.read_csv("combined_spain.csv")

# %% [markdown]
# ### SWEDEN

# %%
extension = 'csv'
sweden_all_filenames = [i for i in glob.glob('../data/sweden/*.csv')]

# %%
#combine all files in the list
sweden_combined_csv = pd.concat([pd.read_csv(f) for f in sweden_all_filenames ])
#export to csv
sweden_combined_csv.to_csv( "combined_sweden.csv", index=False, encoding='utf-8-sig')

# %%
df_sweden = pd.read_csv("combined_sweden.csv")

# %% [markdown]
# ### NETHERLANDS

# %%
extension = 'csv'
netherlands_all_filenames = [i for i in glob.glob('../data/netherlands/*.csv')]

# %%
#combine all files in the list
netherlands_combined_csv = pd.concat([pd.read_csv(f) for f in netherlands_all_filenames ])
#export to csv
netherlands_combined_csv.to_csv( "combined_netherlands.csv", index=False, encoding='utf-8-sig')

# %%
df_netherlands = pd.read_csv("combined_netherlands.csv")

# %% [markdown]
# ## AFRICA

# %% [markdown]
# ### MOROCCO

# %%
extension = 'csv'
morocco_all_filenames = [i for i in glob.glob('../data/morocco/*.csv')]

# %%
#combine all files in the list
morocco_combined_csv = pd.concat([pd.read_csv(f) for f in morocco_all_filenames ])
#export to csv
morocco_combined_csv.to_csv( "combined_morocco.csv", index=False, encoding='utf-8-sig')

# %%
df_morocco = pd.read_csv("combined_morocco.csv")

# %% [markdown]
# ### MALAWI

# %%
extension = 'csv'
malawi_all_filenames = [i for i in glob.glob('../data/malawi/*.csv')]

# %%
#combine all files in the list
malawi_combined_csv = pd.concat([pd.read_csv(f) for f in malawi_all_filenames ])
#export to csv
malawi_combined_csv.to_csv( "combined_malawi.csv", index=False, encoding='utf-8-sig')

# %%
df_malawi = pd.read_csv("combined_malawi.csv")

# %% [markdown]
# ### SOUTH AFRICA

# %%
extension = 'csv'
south_africa_all_filenames = [i for i in glob.glob('../data/south_africa/*.csv')]

# %%
#combine all files in the list
south_africa_combined_csv = pd.concat([pd.read_csv(f) for f in south_africa_all_filenames ])
#export to csv
south_africa_combined_csv.to_csv( "combined_south_africa.csv", index=False, encoding='utf-8-sig')

# %%
df_south_africa = pd.read_csv("combined_south_africa.csv")

# %% [markdown]
# ## AUSTRALIA

# %%
extension = 'csv'
australia_all_filenames = [i for i in glob.glob('../data/australia/*.csv')]

# %%
#combine all files in the list
australia_combined_csv = pd.concat([pd.read_csv(f) for f in australia_all_filenames ])
#export to csv
australia_combined_csv.to_csv( "combined_australia.csv", index=False, encoding='utf-8-sig')

# %%
df_australia = pd.read_csv("combined_australia.csv")

# %% [markdown]
# # Creating the tables

# %% [markdown]
# ##  DFs

# %%
df_temp_india = df_india[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_china = df_china[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_brazil = df_brazil[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_usa = df_usa[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_australia = df_australia[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_south_africa = df_south_africa[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_malawi = df_malawi[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_morocco = df_morocco[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_sweden = df_sweden[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_spain = df_spain[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_germany = df_germany[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_france = df_france[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_romania = df_romania[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_russia = df_russia[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_japan = df_japan[['date_time', 'tempC', 'precipMM']]

# %%
df_temp_netherlands = df_netherlands[['date_time', 'tempC', 'precipMM']]

# %% [markdown]
# # PLOTTING

# %%
df_temp_india.head()
# Out:
#     date_time  tempC  precipMM
# 0  2008-08-10     34       5.9
# 1  2008-08-11     31       4.3
# 2  2008-08-12     30      16.7
# 3  2008-08-13     31      10.4
# 4  2008-08-14     31       6.8

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_india.date_time, df_india.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_india.date_time, df_india.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_india = pd.read_csv("combined_india.csv")

avg_temp_india = df_india.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_india = avg_temp_india.join(df_india['precipMM'])
avg_temp_df_india

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_india.date_time, avg_temp_df_india.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_india.date_time, avg_temp_df_india.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_australia.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_australia.date_time, df_australia.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_australia.date_time, df_australia.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_australia = pd.read_csv("combined_australia.csv")

avg_temp_australia = df_australia.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_australia = avg_temp_australia.join(df_australia['precipMM'])
avg_temp_df_australia

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_australia.date_time, avg_temp_df_australia.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_australia.date_time, avg_temp_df_australia.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_south_africa.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_south_africa.date_time, df_south_africa.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_south_africa.date_time, df_south_africa.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_south_africa = pd.read_csv("combined_south_africa.csv")

avg_temp_south_africa = df_south_africa.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_south_africa = avg_temp_south_africa.join(df_south_africa['precipMM'])
avg_temp_df_south_africa

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_south_africa.date_time, avg_temp_df_south_africa.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_south_africa.date_time, avg_temp_df_south_africa.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_malawi.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_malawi.date_time, df_malawi.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_malawi.date_time, df_malawi.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_malawi = pd.read_csv("combined_malawi.csv")

avg_temp_malawi = df_malawi.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_malawi = avg_temp_malawi.join(df_malawi['precipMM'])
avg_temp_df_malawi

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_malawi.date_time, avg_temp_df_malawi.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_malawi.date_time, avg_temp_df_malawi.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_morocco.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_morocco.date_time, df_morocco.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_morocco.date_time, df_morocco.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_morocco = pd.read_csv("combined_morocco.csv")

avg_temp_morocco = df_morocco.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_morocco = avg_temp_morocco.join(df_morocco['precipMM'])
avg_temp_df_morocco

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_morocco.date_time, avg_temp_df_morocco.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_morocco.date_time, avg_temp_df_morocco.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_sweden.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_sweden.date_time, df_sweden.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_sweden.date_time, df_sweden.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_sweden = pd.read_csv("combined_sweden.csv")

avg_temp_sweden = df_sweden.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_sweden = avg_temp_sweden.join(df_sweden['precipMM'])
avg_temp_df_sweden

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_sweden.date_time, avg_temp_df_sweden.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_sweden.date_time, avg_temp_df_sweden.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_spain.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_spain.date_time, df_spain.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_spain.date_time, df_spain.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_spain = pd.read_csv("combined_spain.csv")

avg_temp_spain = df_spain.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_spain = avg_temp_spain.join(df_spain['precipMM'])
avg_temp_df_spain

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_spain.date_time, avg_temp_df_spain.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_spain.date_time, avg_temp_df_spain.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_germany.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_germany.date_time, df_germany.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_germany.date_time, df_germany.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_germany= pd.read_csv("combined_germany.csv")

avg_temp_germany = df_germany.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_germany = avg_temp_germany.join(df_germany['precipMM'])
avg_temp_df_germany

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_germany.date_time, avg_temp_df_germany.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_germany.date_time, avg_temp_df_germany.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_france.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_france.date_time, df_france.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_france.date_time, df_france.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_france = pd.read_csv("combined_france.csv")

avg_temp_france = df_france.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_france = avg_temp_france.join(df_france['precipMM'])
avg_temp_df_france

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_france.date_time, avg_temp_df_france.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_france.date_time, avg_temp_df_france.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_romania.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_romania.date_time, df_romania.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_romania.date_time, df_romania.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_romania = pd.read_csv("combined_romania.csv")

avg_temp_romania = df_romania.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_romania = avg_temp_romania.join(df_romania['precipMM'])
avg_temp_df_romania

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_romania.date_time, avg_temp_df_romania.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_romania.date_time, avg_temp_df_romania.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_russia.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_russia.date_time, df_russia.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_russia.date_time, df_russia.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_russia = pd.read_csv("combined_russia.csv")

avg_temp_russia = df_russia.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_russia = avg_temp_russia.join(df_russia['precipMM'])
avg_temp_df_russia

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_russia.date_time, avg_temp_df_russia.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_russia.date_time, avg_temp_df_russia.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_netherlands.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_netherlands.date_time, df_netherlands.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_netherlands.date_time, df_netherlands.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_netherlands = pd.read_csv("combined_netherlands.csv")

avg_temp_netherlands = df_netherlands.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_netherlands = avg_temp_netherlands.join(df_netherlands['precipMM'])
avg_temp_df_netherlands

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_netherlands.date_time, avg_temp_df_netherlands.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_netherlands.date_time, avg_temp_df_netherlands.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_japan.head()

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_japan.date_time, df_japan.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_japan.date_time, df_japan.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_japan = pd.read_csv("combined_japan.csv")

avg_temp_japan = df_japan.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_japan = avg_temp_japan.join(df_japan['precipMM'])
avg_temp_df_japan

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_japan.date_time, avg_temp_df_japan.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_japan.date_time, avg_temp_df_japan.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_china.head()
# Out:
#     date_time  tempC  precipMM
# 0  2008-08-10     30      14.7
# 1  2008-08-11     27       3.6
# 2  2008-08-12     28       1.9
# 3  2008-08-13     28       1.0
# 4  2008-08-14     27       2.7

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_china.date_time, df_china.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_china.date_time, df_china.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_china = pd.read_csv("combined_china.csv")

avg_temp_china = df_china.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_china = avg_temp_china.join(df_china['precipMM'])
avg_temp_df_china

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_china.date_time, avg_temp_df_china.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_china.date_time, avg_temp_df_china.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_brazil.head()
# Out:
#     date_time  tempC  precipMM
# 0  2008-08-10     23       1.4
# 1  2008-08-11     26       0.1
# 2  2008-08-12     28       0.0
# 3  2008-08-13     28       0.0
# 4  2008-08-14     25       0.0

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_brazil.date_time, df_brazil.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_brazil.date_time, df_brazil.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_brazil = pd.read_csv("combined_brazil.csv")

avg_temp_brazil = df_brazil.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_brazil = avg_temp_brazil.join(df_brazil['precipMM'])
avg_temp_df_brazil

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_brazil.date_time, avg_temp_df_brazil.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_brazil.date_time, avg_temp_df_brazil.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_temp_usa.head()
# Out:
#     date_time  tempC  precipMM
# 0  2008-08-10     30       0.0
# 1  2008-08-11     32       0.0
# 2  2008-08-12     26       0.4
# 3  2008-08-13     26       1.5
# 4  2008-08-14     30       0.4

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_usa.date_time, df_usa.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_usa.date_time, df_usa.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
df_usa = pd.read_csv("combined_usa.csv")

avg_temp_usa = df_usa.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df_usa = avg_temp_usa.join(df_usa['precipMM'])
avg_temp_df_usa

# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df_usa.date_time, avg_temp_df_usa.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df_usa.date_time, avg_temp_df_usa.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %% [markdown]
# ## 5 Year Analysis

# %%
df_india_time_range_0813 = avg_temp_df_india.loc[(avg_temp_df_india['date_time'] >= '2008-08-10') & (avg_temp_df_india['date_time'] < '2013-08-11')]

# %%
x_india_5y = df_india_time_range_0813['date_time']
y_india_5y = df_india_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_india_5y, y_india_5y)

plt.show()

# %%
df_china_time_range_0813 = avg_temp_df_china.loc[(avg_temp_df_china['date_time'] >= '2008-08-10') & (avg_temp_df_china['date_time'] < '2013-08-11')]

# %%
x_china_5y = df_china_time_range_0813['date_time']
y_china_5y = df_china_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_china_5y, y_china_5y)

plt.show()

# %%
df_brazil_time_range_08_fin = avg_temp_df_brazil.loc[(avg_temp_df_brazil['date_time'] >= '2008-08-10') & (avg_temp_df_brazil['date_time'] < '2008-12-30')]

# %%
x_brazil_5y = df_brazil_time_range_08_fin['date_time']
y_brazil_5y = df_brazil_time_range_08_fin['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_brazil_5y, y_brazil_5y)

plt.show()

# %%
df_usa_time_range_0813 = avg_temp_df_usa.loc[(avg_temp_df_usa['date_time'] >= '2008-08-10') & (avg_temp_df_usa['date_time'] < '2013-08-11')]

# %%
x_usa_5y = df_usa_time_range_0813['date_time']
y_usa_5y = df_usa_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_usa_5y, y_usa_5y)

plt.show()

# %%
df_japan_time_range_0813 = avg_temp_df_japan.loc[(avg_temp_df_japan['date_time'] >= '2008-08-10') & (avg_temp_df_japan['date_time'] < '2013-08-11')]

x_japan_5y = df_japan_time_range_0813['date_time']
y_japan_5y = df_japan_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_japan_5y, y_japan_5y)

plt.show()

# %%
df_russia_time_range_0813 = avg_temp_df_russia.loc[(avg_temp_df_russia['date_time'] >= '2008-08-10') & (avg_temp_df_russia['date_time'] < '2013-08-11')]

x_russia_5y = df_russia_time_range_0813['date_time']
y_russia_5y = df_russia_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_russia_5y, y_russia_5y)

plt.show()

# %%
df_romania_time_range_0813 = avg_temp_df_romania.loc[(avg_temp_df_romania['date_time'] >= '2008-08-10') & (avg_temp_df_romania['date_time'] < '2013-08-11')]

x_romania_5y = df_romania_time_range_0813['date_time']
y_romania_5y = df_romania_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_romania_5y, y_romania_5y)

plt.show()

# %%
df_france_time_range_0813 = avg_temp_df_france.loc[(avg_temp_df_france['date_time'] >= '2008-08-10') & (avg_temp_df_france['date_time'] < '2013-08-11')]

x_france_5y = df_france_time_range_0813['date_time']
y_france_5y = df_france_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_france_5y, y_france_5y)

plt.show()

# %%
df_germany_time_range_0813 = avg_temp_df_germany.loc[(avg_temp_df_germany['date_time'] >= '2008-08-10') & (avg_temp_df_germany['date_time'] < '2013-08-11')]

x_germany_5y = df_germany_time_range_0813['date_time']
y_germany_5y = df_germany_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_germany_5y, y_germany_5y)

plt.show()

# %%
df_spain_time_range_0813 = avg_temp_df_spain.loc[(avg_temp_df_spain['date_time'] >= '2008-08-10') & (avg_temp_df_spain['date_time'] < '2013-08-11')]

x_spain_5y = df_spain_time_range_0813['date_time']
y_spain_5y = df_spain_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_spain_5y, y_spain_5y)

plt.show()

# %%
df_sweden_time_range_0813 = avg_temp_df_sweden.loc[(avg_temp_df_sweden['date_time'] >= '2008-08-10') & (avg_temp_df_sweden['date_time'] < '2013-08-11')]

x_sweden_5y = df_sweden_time_range_0813['date_time']
y_sweden_5y = df_sweden_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_sweden_5y, y_sweden_5y)

plt.show()

# %%
df_netherlands_time_range_0813 = avg_temp_df_netherlands.loc[(avg_temp_df_netherlands['date_time'] >= '2008-08-10') & (avg_temp_df_netherlands['date_time'] < '2013-08-11')]

x_netherlands_5y = df_netherlands_time_range_0813['date_time']
y_netherlands_5y = df_netherlands_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_netherlands_5y, y_netherlands_5y)

plt.show()

# %%
fig, axs = plt.subplots(4)
fig.suptitle('Weather Data Analysis 5 Years Comparison')
plt.subplots_adjust(bottom=0.1)
axs[0].set_title('USA')
axs[0].plot(x_usa_5y, y_usa_5y)
axs[1].set_title('Brazil')
axs[1].plot(x_brazil_5y, y_brazil_5y, 'tab:orange')
axs[2].set_title('China')
axs[2].plot(x_china_5y, y_china_5y, 'tab:green')
axs[3].set_title('India')
axs[3].plot(x_india_5y, y_india_5y, 'tab:red')

# %% [markdown]
# ## 1 Year Analysis

# %%
df_india_time_range_0809 = df_temp_india.loc[(df_temp_india['date_time'] >= '2008-08-10') & (df_temp_india['date_time'] < '2009-08-10')]

# %%
x_india_1y = df_india_time_range_0809['date_time']
y_india_1y = df_india_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_india_1y, y_india_1y)

plt.show()

# %%
df_china_time_range_0809 = df_temp_china.loc[(df_temp_china['date_time'] >= '2008-08-10') & (df_temp_china['date_time'] < '2009-08-10')]

# %%
x_china_1y = df_china_time_range_0809['date_time']
y_china_1y = df_china_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_china_1y, y_china_1y)

plt.show()

# %%
df_brazil_time_range_0809 = df_temp_brazil.loc[(df_temp_brazil['date_time'] >= '2008-08-10') & (df_temp_brazil['date_time'] < '2009-08-10')]

# %%
x_brazil_1y = df_brazil_time_range_0809['date_time']
y_brazil_1y = df_brazil_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_brazil_1y, y_brazil_1y)

plt.show()

# %%
df_usa_time_range_0809 = df_temp_usa.loc[(df_temp_usa['date_time'] >= '2008-08-10') & (df_temp_usa['date_time'] < '2009-08-10')]

# %%
x_usa_1y = df_usa_time_range_0809['date_time']
y_usa_1y = df_usa_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x_usa_1y, y_usa_1y)

plt.show()
