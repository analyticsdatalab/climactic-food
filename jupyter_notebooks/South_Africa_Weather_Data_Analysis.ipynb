# %%
import os
import glob
import pandas as pd

from matplotlib import pyplot as plt

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('../data/south_africa/*.csv')]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_south_africa.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("combined_south_africa.csv")

# %%
avg_temp = df.groupby('date_time', as_index=False)['tempC'].mean()
avg_temp_df = avg_temp.join(df['precipMM'])
avg_temp_df
# Out:
#        date_time      tempC  precipMM
# 0     2008-08-10  20.666667       0.0
# 1     2008-08-11  21.666667       0.0
# 2     2008-08-12  22.111111       0.0
# 3     2008-08-13  21.333333       0.0
# 4     2008-08-14  23.555556       0.0
# ...          ...        ...       ...
# 3861  2019-03-07  29.555556       4.7
# 3862  2019-03-08  26.333333       3.2
# 3863  2019-03-09  26.555556       4.1
# 3864  2019-03-10  27.888889       6.5
# 3865  2019-03-11  25.222222      17.8
#
# [3866 rows x 3 columns]

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(avg_temp_df.date_time, avg_temp_df.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(avg_temp_df.date_time, avg_temp_df.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_south_africa_all.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Year Analysis

# %%
df_south_africa_time_range_0813 = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2013-08-11')]

# %%
x = df_south_africa_time_range_0813['date_time']
y = df_south_africa_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_south_africa_time_range_0813.date_time, df_south_africa_time_range_0813.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_south_africa_time_range_0813.date_time, df_south_africa_time_range_0813.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_south_africa_5years.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ##  1 Year Analysis

# %%
df_south_africa_time_range_0809 = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2009-08-10')]

# %%
x = df_south_africa_time_range_0809['date_time']
y = df_south_africa_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_south_africa_time_range_0809.date_time, df_south_africa_time_range_0809.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_south_africa_time_range_0809.date_time, df_aouth_africa_time_range_0809.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-4b27fc0936f4> in <module>
#       9 ax2=ax.twinx()
#      10 # make a plot with different y-axis using second axis object
# ---> 11 ax2.plot(df_south_africa_time_range_0809.date_time, df_aouth_africa_time_range_0809.precipMM,color="blue",marker="o")
#      12 ax2.set_ylabel("precipMM",color="blue",fontsize=14)
#      13 plt.show()
#
# NameError: name 'df_aouth_africa_time_range_0809' is not defined

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_south_africa_1year.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Months Analysis

# %%
df_south_africa_time_range_08_fin = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2008-12-30')]

# %%
x = df_south_africa_time_range_08_fin['date_time']
y = df_south_africa_time_range_08_fin['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_south_africa_time_range_08_fin.date_time, df_south_africa_time_range_08_fin.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_south_africa_time_range_08_fin.date_time, df_south_africa_time_range_08_fin.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_south_africa_5months.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Month Analysis

# %%
df_south_africa_time_range_08_aug = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2008-08-30')]

# %%
x = df_south_africa_time_range_08_aug['date_time']
y = df_south_africa_time_range_08_aug['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_south_africa_time_range_08_aug.date_time, df_south_africa_time_range_08_aug.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_south_africa_time_range_08_aug.date_time, df_south_africa_time_range_08_aug.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_south_africa_aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Week Analysis

# %%
df_south_africa_time_range_08_w1 = avg_temp_df.loc[(avg_temp_df['date_time'] >= '2008-08-10') & (avg_temp_df['date_time'] < '2008-08-17')]

# %%
x = df_south_africa_time_range_08_w1['date_time']
y = df_south_africa_time_range_08_w1['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_japan_time_range_08_w1.date_time, df_japan_time_range_08_w1.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_japan_time_range_08_w1.date_time, df_japan_time_range_08_w1.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()
