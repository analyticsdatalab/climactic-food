# %%
import pandas as pd

from matplotlib import pyplot as plt

# %% [markdown]
# # Brazil Data Analysis

# %%
import os
import glob
import pandas as pd

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('../data/brazil/*.csv')]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_brazil.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("combined_brazil.csv")

# %% [markdown]
# # Descriptive Data

# %%
df.head(10)
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2008-08-10        23        15           0.0      8.7        4
# 1  2008-08-11        26        14           0.0      8.7        5
# 2  2008-08-12        28        17           0.0      8.7        6
# 3  2008-08-13        28        18           0.0      8.7        6
# 4  2008-08-14        25        17           0.0      8.7        6
# 5  2008-08-15        27        16           0.0      8.7        6
# 6  2008-08-16        27        17           0.0      8.7        6
# 7  2008-08-17        28        17           0.0      8.7        6
# 8  2008-08-18        29        16           0.0      8.7        6
# 9  2008-08-19        29        16           0.0      8.7        6
#
#    moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 0                 57  12:25 PM  01:37 AM  06:37 AM  ...           16
# 1                 65  01:14 PM  02:31 AM  06:37 AM  ...           11
# ...

# %%
df.tail()
# Out:
#         date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 46387  2019-03-07        30        23           0.0      9.2        6
# 46388  2019-03-08        32        23           0.0      7.8        6
# 46389  2019-03-09        32        23           0.0      9.2        6
# 46390  2019-03-10        32        23           0.0      7.8        6
# 46391  2019-03-11        32        23           0.0     10.5        6
#
#        moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 46387                  3  06:37 AM  07:01 PM  05:57 AM  ...            7
# 46388                 10  07:21 AM  07:42 PM  05:57 AM  ...            7
# 46389                 17  08:05 AM  08:23 PM  05:57 AM  ...            8
# 46390                 24  08:51 AM  09:06 PM  05:57 AM  ...            8
# 46391                 32  09:38 AM  09:51 PM  05:57 AM  ...            6
#
#        cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
df.describe()
# Out:
#            maxtempC      mintempC  totalSnow_cm       sunHour       uvIndex  \
# count  46392.000000  46392.000000       46392.0  46392.000000  46392.000000
# mean      28.703699     21.157980           0.0     10.650543      5.921280
# std        3.967434      3.831036           0.0      1.949240      0.943815
# min        7.000000      3.000000           0.0      4.100000      2.000000
# 25%       26.000000     19.000000           0.0      8.800000      5.000000
# 50%       29.000000     22.000000           0.0     11.600000      6.000000
# 75%       31.000000     24.000000           0.0     11.600000      6.000000
# max       42.000000     31.000000           0.0     13.700000      9.000000
#
#        moon_illumination     DewPointC    FeelsLikeC    HeatIndexC  \
# count       46392.000000  46392.000000  46392.000000  46392.000000
# mean           46.107346     19.839541     26.623664     26.713011
# std            31.277118      3.492076      4.451673      4.307096
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46392 entries, 0 to 46391
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          46392 non-null  object
#  1   maxtempC           46392 non-null  int64
#  2   mintempC           46392 non-null  int64
#  3   totalSnow_cm       46392 non-null  float64
#  4   sunHour            46392 non-null  float64
#  5   uvIndex            46392 non-null  int64
#  6   moon_illumination  46392 non-null  int64
#  7   moonrise           46392 non-null  object
#  8   moonset            46392 non-null  object
#  9   sunrise            46392 non-null  object
#  10  sunset             46392 non-null  object
#  11  DewPointC          46392 non-null  int64
#  12  FeelsLikeC         46392 non-null  int64
#  13  HeatIndexC         46392 non-null  int64
#  14  WindChillC         46392 non-null  int64
#  15  WindGustKmph       46392 non-null  int64
# ...

# %%
df_temp = df[['date_time', 'tempC', 'precipMM']]

# %%
df_temp.head()
# Out:
#     date_time  tempC  precipMM
# 0  2008-08-10     23       1.4
# 1  2008-08-11     26       0.1
# 2  2008-08-12     28       0.0
# 3  2008-08-13     28       0.0
# 4  2008-08-14     25       0.0

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df.date_time, df.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df.date_time, df.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_usa_all.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Year Analysis

# %%
df_brazil_time_range_0813 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2013-08-11')]

# %%
x = df_brazil_time_range_0813['date_time']
y = df_brazil_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_brazil_time_range_0813.date_time, df_brazil_time_range_0813.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_brazil_time_range_0813.date_time, df_brazil_time_range_0813.precipMM,color="blue",marker="x")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_brazil_5years.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# # 1 Year Analysis

# %%
df_brazil_time_range_0809 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2009-08-10')]

# %%
x = df_brazil_time_range_0809['date_time']
y = df_brazil_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_brazil_time_range_0809.date_time, df_brazil_time_range_0809.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_brazil_time_range_0809.date_time, df_brazil_time_range_0809.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_brazil_1year.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Months Analysis

# %%
df_brazil_time_range_08_fin = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-12-30')]

# %%
x = df_brazil_time_range_08_fin['date_time']
y = df_brazil_time_range_08_fin['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_brazil_time_range_08_fin.date_time, df_brazil_time_range_08_fin.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_brazil_time_range_08_fin.date_time, df_brazil_time_range_08_fin.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b3fc6c3a6c71> in <module>
#       2 fig,ax = plt.subplots()
#       3 # make a plot
# ----> 4 ax.plot(df_brazil_time_range_08_fin.date_time, df_brazil_time_range_08_fin.tempC, color="red", marker="o")
#       5 # set x-axis label
#       6 ax.set_xlabel("date_time",fontsize=14)
#
# NameError: name 'df_brazil_time_range_08_fin' is not defined

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_brazil_5months.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Month Analysis

# %%
df_brazil_time_range_08_aug = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-08-30')]

# %%
x = df_brazil_time_range_08_aug['date_time']
y = df_brazil_time_range_08_aug['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_brazil_time_range_08_aug.date_time, df_brazil_time_range_08_aug.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_brazil_time_range_08_aug.date_time, df_brazil_time_range_08_aug.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_brazil_aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Week Analysis

# %%
df_brazil_time_range_08_w1 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-08-17')]

# %%
x = df_brazil_time_range_08_w1['date_time']
y = df_brazil_time_range_08_w1['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_brazil_time_range_08_w1.date_time, df_brazil_time_range_08_w1.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_brazil_time_range_08_w1.date_time, df_brazil_time_range_08_w1.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_brazil_1week.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Day Analysis

# %%
df_brazil_time_range_08_d10 = df_temp.loc[(df_temp['date_time'] == '2008-08-10')]

# %%
x = df_brazil_time_range_08_d10['date_time']
y = df_brazil_time_range_08_d10['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_brazil_time_range_08_d10.date_time, df_brazil_time_range_08_d10.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_brazil_time_range_08_d10.date_time, df_brazil_time_range_08_d10.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_brazil_10aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
