# %%
import pandas as pd

from matplotlib import pyplot as plt

# %% [markdown]
# # China Data Analysis

# %%
import os
import glob
import pandas as pd

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('../data/china/*.csv')]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_china.csv", index=False, encoding='utf-8-sig')

# %%
df = pd.read_csv("combined_china.csv")

# %% [markdown]
# ## Descriptive Data

# %%
df.head(10)
# Out:
#     date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 0  2008-08-10        30        21           0.0     11.0        6
# 1  2008-08-11        27        20           0.0     13.3        5
# 2  2008-08-12        28        20           0.0     13.3        6
# 3  2008-08-13        28        19           0.0     13.9        6
# 4  2008-08-14        27        18           0.0     13.9        5
# 5  2008-08-15        28        18           0.0     13.9        6
# 6  2008-08-16        28        17           0.0     13.8        6
# 7  2008-08-17        25        17           0.0     13.8        6
# 8  2008-08-18        28        16           0.0     13.8        6
# 9  2008-08-19        30        16           0.0     13.8        7
#
#    moon_illumination  moonrise     moonset   sunrise  ... WindGustKmph  \
# 0                 57  02:37 PM    11:39 PM  05:22 AM  ...           12
# 1                 65  03:35 PM  No moonset  05:23 AM  ...           11
# ...

# %%
df.tail()
# Out:
#         date_time  maxtempC  mintempC  totalSnow_cm  sunHour  uvIndex  \
# 42521  2019-03-07        17        14           0.0      5.9        4
# 42522  2019-03-08        17        13           0.0      5.9        3
# 42523  2019-03-09        16        14           0.0      6.0        4
# 42524  2019-03-10        18        14           0.0      8.8        4
# 42525  2019-03-11        20        17           0.0     11.6        4
#
#        moon_illumination  moonrise   moonset   sunrise  ... WindGustKmph  \
# 42521                  3  06:52 AM  06:46 PM  06:25 AM  ...           39
# 42522                 10  07:26 AM  07:37 PM  06:24 AM  ...           30
# 42523                 17  08:00 AM  08:28 PM  06:23 AM  ...           13
# 42524                 24  08:34 AM  09:21 PM  06:22 AM  ...            7
# 42525                 32  09:11 AM  10:14 PM  06:21 AM  ...           14
#
#        cloudcover  humidity  precipMM  pressure  tempC  visibility  \
# ...

# %%
df.describe()
# Out:
#            maxtempC      mintempC  totalSnow_cm       sunHour       uvIndex  \
# count  42526.000000  42526.000000  42526.000000  42526.000000  42526.000000
# mean      19.993486     12.590674      0.012839     10.235186      4.622960
# std       11.037548     10.998430      0.172966      2.844738      1.929459
# min      -26.000000    -42.000000      0.000000      3.200000      1.000000
# 25%       13.000000      5.000000      0.000000      8.700000      3.000000
# 50%       22.000000     15.000000      0.000000     10.300000      5.000000
# 75%       29.000000     21.000000      0.000000     12.800000      6.000000
# max       41.000000     32.000000     16.400000     14.500000      9.000000
#
#        moon_illumination     DewPointC    FeelsLikeC    HeatIndexC  \
# count       42526.000000  42526.000000  42526.000000  42526.000000
# mean           46.107346      9.533768     17.169496     18.151437
# std            31.277149     12.639420     13.679795     12.338804
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42526 entries, 0 to 42525
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date_time          42526 non-null  object
#  1   maxtempC           42526 non-null  int64
#  2   mintempC           42526 non-null  int64
#  3   totalSnow_cm       42526 non-null  float64
#  4   sunHour            42526 non-null  float64
#  5   uvIndex            42526 non-null  int64
#  6   moon_illumination  42526 non-null  int64
#  7   moonrise           42526 non-null  object
#  8   moonset            42526 non-null  object
#  9   sunrise            42526 non-null  object
#  10  sunset             42526 non-null  object
#  11  DewPointC          42526 non-null  int64
#  12  FeelsLikeC         42526 non-null  int64
#  13  HeatIndexC         42526 non-null  int64
#  14  WindChillC         42526 non-null  int64
#  15  WindGustKmph       42526 non-null  int64
# ...

# %%
df_temp = df[['date_time', 'tempC', 'precipMM']]

# %%
df_temp.head()
# Out:
#     date_time  tempC  precipMM
# 0  2008-08-10     30      14.7
# 1  2008-08-11     27       3.6
# 2  2008-08-12     28       1.9
# 3  2008-08-13     28       1.0
# 4  2008-08-14     27       2.7

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df.date_time, df.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df.date_time, df.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_china_all.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Year Analysis

# %%
df_china_time_range_0813 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2013-08-11')]

# %%
x = df_china_time_range_0813['date_time']
y = df_china_time_range_0813['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_china_time_range_0813.date_time, df_china_time_range_0813.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_china_time_range_0813.date_time, df_china_time_range_0813.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_china_5years.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Year Analysis

# %%
df_china_time_range_0809 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2009-08-10')]

# %%
x = df_china_time_range_0809['date_time']
y = df_china_time_range_0809['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_china_time_range_0809.date_time, df_china_time_range_0809.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_china_time_range_0809.date_time, df_china_time_range_0809.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_china_1year.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 5 Months Analysis

# %%
df_china_time_range_08_fin = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-12-30')]

# %%
x = df_china_time_range_08_fin['date_time']
y = df_china_time_range_08_fin['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_china_time_range_08_fin.date_time, df_china_time_range_08_fin.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_china_time_range_08_fin.date_time, df_china_time_range_08_fin.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_china_5months.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Month Analysis

# %%
df_china_time_range_08_aug = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-08-30')]

# %%
x = df_china_time_range_08_aug['date_time']
y = df_china_time_range_08_aug['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_china_time_range_08_aug.date_time, df_china_time_range_08_aug.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_china_time_range_08_aug.date_time, df_china_time_range_08_aug.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_china_aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Week Analysis

# %%
df_china_time_range_08_w1 = df_temp.loc[(df_temp['date_time'] >= '2008-08-10') & (df_temp['date_time'] < '2008-08-17')]

# %%
x = df_china_time_range_08_w1['date_time']
y = df_china_time_range_08_w1['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_china_time_range_08_w1.date_time, df_china_time_range_08_w1.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_china_time_range_08_w1.date_time, df_china_time_range_08_w1.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_china_1week.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')

# %% [markdown]
# ## 1 Day Analysis

# %%
df_china_time_range_08_d10 = df_temp.loc[(df_temp['date_time'] == '2008-08-10')]

# %%
x = df_china_time_range_08_d10['date_time']
y = df_china_time_range_08_d10['tempC']

plt.figure(figsize=(15,5))
plt.scatter(x, y)

plt.show()

# %%
# create figure and axis objects with subplots()
fig,ax = plt.subplots()
# make a plot
ax.plot(df_china_time_range_08_d10.date_time, df_china_time_range_08_d10.tempC, color="red", marker="o")
# set x-axis label
ax.set_xlabel("date_time",fontsize=14)
# set y-axis label
ax.set_ylabel("tempC",color="red",fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df_china_time_range_08_d10.date_time, df_china_time_range_08_d10.precipMM,color="blue",marker="o")
ax2.set_ylabel("precipMM",color="blue",fontsize=14)
plt.show()

# %%
# save the plot as a file
fig.savefig('precipitations_temperatures_china_10aug.jpg',
            format='jpeg',
            dpi=100,
            bbox_inches='tight')
